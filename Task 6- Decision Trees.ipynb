# %% [markdown]
# # Shreya Mitra
# ## Task - 6 The Sparks Foundation (Data Science and Business Analytics Internship)

# %% [markdown]
# This task is about classification using the decision tree algoithm and representation of it graphically. The point of this task is to build a classifier such that after feeding new data, it can be classified correctly too.

# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree

# %%
data = pd.read_csv("C://Users//Lenovo//Downloads//iris.csv")

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#Checking for null values
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# There are no null values in the dataset.

# %%
#to know the type of each column values
data.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
#to know the type of each column values
data.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
#For checking the relationship between the features (colmumn names) of the dataset
#for pairwise comparision 'Id' variable is not of use
df = data.iloc[:,1:6]

# %%
sns.pairplot(df, hue = 'Species')

# %% [markdown]
# Most of them are already separated on basis of these properties. There are a few anomalies, but not enough to be considered as a problem.

# %%
#Splitting of the data into training and testing
#First we separate the data into X and Y variables
X = data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']].values
Y = data['Species'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=0, train_size=0.7)

# %%
#Building the classifier
from sklearn.tree import DecisionTreeClassifier
dfc = DecisionTreeClassifier()
dfc.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#Checking the accuracy of the model with the help of testing data
score = dfc.score(X_test, Y_test)
print(score)
# Out:
# 0.9777777777777777

# %% [markdown]
# The accuracy score of our model is pretty high

# %%
import sklearn.datasets as datasets
iris=datasets.load_iris()
# Visualize the graph
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dfc, 
                   feature_names=iris.feature_names,  
                   class_names=iris.target_names,
                   filled=True)

# %% [markdown]
# The task is complete.
